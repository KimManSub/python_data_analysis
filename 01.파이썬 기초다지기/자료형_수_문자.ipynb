# %%
a=10.2M
b=5

d="10.2"
c="5"

type(b)
type(c)

a+b

c+d

yearInfo ="202410"
weekInfo="15"
yearweekInfo =weekInfo + yearInfo
yearweekInfo

###연주자정보가 주어 졌습니다 : 202410
###연도와 주차정보를 분리해보세요~!!

###인덱스가 나오기 시작함 
###yearweekInfo="202410"
###012345 각각의 인덱스값을 가지고 있음 <- 한글자마다

yearIndex = 4

yearInfo=yearweekInfo[0:yearIndex]
weekInfo =yeareekInfo[4:]
weekInfo

balance = 150000

if (balance < 100000) :
    print("국민상품")
else : 
    print("플래그쉽상품")

#연도와 주차를 INDEX를 활용해서 추출 
yearweekInfo ="2024W28"
specificChar ="W"
specificCharIndex=yearweekInfo.index(specificChar)
yearInfo =yearweekInfo[:specificCharIndex]
weekInfo = yearweekInfo[specificCharIndex+1:]

specificCharIndex=yearweekInfo.index(specificChar)
specificCharIndex

yearInfo


weekInfo

inputId ="haiteam"

inputId.upper()

password ="haiteam"

if inputId.lower() == password.lower():
    print("로그인 성공")
else:
    print("로그인 실패")

inYearweek ="2024_24"


usaStd = "_"
korStd = "W"
inYearweek.replace(usaStd, korStd)

### split

answer=inYearweek.split(usaStd)


### ""면 ''  '' 면 "" 이것도 싫다 """ """

type(answer)

###리스트는 여러 집합을 저장한다!

answer[0]

len(inYearweek)

inDate = 202410 
yearIndex =4
strDate= str(inDate)
strDate[0:yearIndex]

print(type(inDate))
print(type(strDate))

int(202410/100)

202410%100

##숫자로 하던 문자로 하던 분류만 하면됨

##일단 구현을 하는걸 목표로 삼는걸 목표로 삼는다.

a="202412"

result =float(a)
result

inData="sec 20230212 250"
splitter =" "
answer = inData.split(splitter)



stock_name =answer[0].upper()
date = answer[1]
Value = answer[2]


stock_name

date

Value

###1-3 리스트

scoreList = [80,70,50,20]

type(scoreList)

len(scoreList)

scoreList[0:3]

scoreList[0]

##리스트 삭제,업데이트

#UPDATE (INSERT, UPDATE),DELETE

newScore=560

scoreList.append(newScore)

scoreList[0] =9999

scoreList

maxValue =max(scoreList)
maxValue

scoreList.remove(maxValue)
scoreList

###리스트 중요 포인트 CRUD 할수 있어야함 
###집합중에서 가장 큰값, 가장 작은값, 합 , 길이 append, max

scoreListlen=len(scoreList)
scoreListlen
scoreListSum=sum(scoreList)
scoreListSum
scoreListMax =max(scoreList)
scoreListMax
scoreListMin=min(scoreList)
scoreListMin

#### scoreList = [50,60,70,80,90,100]
### 최소값과 최대값을 제외한 평균을 계산하시오

scoreList = [50,60,70,80,90,100]
scoreListMax =max(scoreList)
scoreList.remove(scoreListMax)

scoreListMin=min(scoreList)
scoreList.remove(scoreListMin)
print(f"최소값 {scoreListMin} 최대값 {scoreListMax}")
scoreListAverage=sum(scoreList)/len(scoreList)
scoreListAverage


### step1 전체 데이터의 최소/최대 값을 구한다
### step2 최소 최대값을 삭제한다
### step3 남은 데이터의 평균을 구한다. 평균 : 합(리스트)/ 길이(리스트)
### 최소한 단계를 나누거나 drwa.io....순서도
### 순서도 그리는건 중요한 포인트임 

scoreList = [90,120,70,80,90,100]
#sort는 주의할점 정렬은 cost가 비싸다!! 안쓸수 있음 안써라
#피할수 있음 피해라
scoreList.sort(reverse=True)
scoreList

scoreList.count(70)

scoreDate ="7070"
scoreDate.count("70")


##avera(sum)/(len) 0이면 그냥 꺼저버림

myList =["apple", "bananan", "orang"]
resultStirng ='_'.join(myList)
resultStirng

수,문자,리스트 


pwd
